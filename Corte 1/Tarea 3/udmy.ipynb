# %%
import pandas as pd

# %% [markdown]
# ### Explicación de la línea
# `import pandas as pd`
# **Importación:** carga **pandas** con el alias `pd` para manipular tablas y series de datos.

# %%
url = "https://data.cityofnewyork.us/resource/rc75-m7u3.csv"

# %% [markdown]
# ### Explicación de la línea
# `url = "https://data.cityofnewyork.us/resource/rc75-m7u3.csv"`
# **Asignación:** guarda en `url` la dirección del CSV remoto con datos de Nueva York.

# %%
#covid = pd.read_csv(url)

# %% [markdown]
# ### Explicación de la línea
# `#covid = pd.read_csv(url)`
# **Comentario:** documenta la intención del ejercicio y no se ejecuta porque comienza con `#`.

# %%
covid = pd.read_csv(url)

# %% [markdown]
# ### Explicación de la línea
# `covid = pd.read_csv(url)`
# **Lectura:** descarga el CSV indicado por `url` y crea el DataFrame `covid`.

# %%
covid.head()

# %% [markdown]
# ### Explicación de la línea
# `covid.head()`
# **Vista previa:** muestra las primeras filas para comprobar la carga y estructura de los datos.

# %%
covid.info()

# %% [markdown]
# ### Explicación de la línea
# `covid.info()`
# **Inspección:** resume columnas, tipos de datos y valores no nulos.

# %%
covid.to_csv('NYC_covid_cases.csv')

# %% [markdown]
# ### Explicación de la línea
# `covid.to_csv('NYC_covid_cases.csv')`
# **Exportación:** guarda el DataFrame como CSV; `columns` limita las columnas exportadas.

# %%
covid.to_csv('NYC1_covid_cases.csv', columns = ['case_count', 'hospitalized_count', 'death_count'])

# %% [markdown]
# ### Explicación de la línea
# `covid.to_csv('NYC1_covid_cases.csv', columns = ['case_count', 'hospitalized_count', 'death_count'])`
# **Exportación:** guarda el DataFrame como CSV; `columns` limita las columnas exportadas.
