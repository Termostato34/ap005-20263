# %%
import pandas as pd

# %% [markdown]
# ### Explicación de la línea
# `import pandas as pd`
# **Importación:** carga **pandas** con el alias `pd` para manipular tablas y series de datos.

# %%
nba = pd.read_excel("/content/drive/MyDrive/udmy/AP005320241/Nba Teams.xlsx")

# %% [markdown]
# ### Explicación de la línea
# `nba = pd.read_excel("/content/drive/MyDrive/udmy/AP005320241/Nba Teams.xlsx")`
# **Lectura:** `pd.read_excel` carga el archivo de Excel en el DataFrame `nba`.

# %%
nba.head()

# %% [markdown]
# ### Explicación de la línea
# `nba.head()`
# **Vista previa:** muestra las primeras filas para comprobar la carga y estructura de los datos.

# %%
from google.colab import drive

# %% [markdown]
# ### Explicación de la línea
# `from google.colab import drive`
# **Importación:** obtiene `drive` de Google Colab para conectar el cuaderno con Google Drive.

# %%
drive.mount('/content/drive')

# %% [markdown]
# ### Explicación de la línea
# `drive.mount('/content/drive')`
# **Montaje:** conecta Google Drive en `/content/drive` para leer archivos almacenados allí.

# %%
from google.colab import drive

# %% [markdown]
# ### Explicación de la línea
# `from google.colab import drive`
# **Importación:** obtiene `drive` de Google Colab para conectar el cuaderno con Google Drive.

# %%
drive.mount('/content/drive')

# %% [markdown]
# ### Explicación de la línea
# `drive.mount('/content/drive')`
# **Montaje:** conecta Google Drive en `/content/drive` para leer archivos almacenados allí.

# %%
nba.head(10)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                 Name           Team   Division Position Height  Weight  \
# 0  Bogdan Bogdanovic  Atlanta Hawks  SouthEast        G    6'6   220.0
# 1    Brandon Goodwin  Atlanta Hawks  SouthEast        G    NaN   180.0
# 2     Bruno Fernando  Atlanta Hawks  SouthEast        F    6'9   240.0
# 3        Cam Reddish  Atlanta Hawks  SouthEast        F    6'8   218.0
# 4       Clint Capela  Atlanta Hawks  SouthEast        C   6'10   240.0
# 5   Danilo Gallinari  Atlanta Hawks  SouthEast        F   6'10   233.0
# 6    De'Andre Hunter  Atlanta Hawks  SouthEast        F    6'7   225.0
# 7       John Collins  Atlanta Hawks  SouthEast        F    6'9   235.0
# 8      Kevin Huerter  Atlanta Hawks  SouthEast        G    6'7   190.0
# 9                NaN            NaN        NaN      NaN    NaN     NaN
#
#   Birth_Date          College      Salary Country
# ...

# %% [markdown]
# ### Explicación de la línea
# `nba.head(10)`
# **Vista previa:** muestra las primeras filas para comprobar la carga y estructura de los datos.

# %%
nba.tail()

# %% [markdown]
# ### Explicación de la línea
# `nba.tail()`
# **Vista final:** muestra las últimas filas del conjunto de datos.

# %%
nbaNoNull = nba.dropna()

# %% [markdown]
# ### Explicación de la línea
# `nbaNoNull = nba.dropna()`
# **Limpieza:** elimina filas o columnas con valores nulos según `how`, `axis` o `subset`.

# %%
nbaNoNull

# %% [markdown]
# ### Explicación de la línea
# `nbaNoNull`
# **Visualización:** muestra el DataFrame `nbaNoNull`, que contiene las filas de `nba` después de eliminar valores nulos.

# %%
nba

# %% [markdown]
# ### Explicación de la línea
# `nba`
# **Visualización:** muestra el contenido actual del objeto en la salida de la celda.

# %%
#nba.dropna(inplace=True)

# %% [markdown]
# ### Explicación de la línea
# `#nba.dropna(inplace=True)`
# **Comentario:** documenta la intención del ejercicio y no se ejecuta porque comienza con `#`.

# %%
nba.dropna()

# %% [markdown]
# ### Explicación de la línea
# `nba.dropna()`
# **Limpieza:** elimina filas o columnas con valores nulos según `how`, `axis` o `subset`.

# %%
nba

# %% [markdown]
# ### Explicación de la línea
# `nba`
# **Visualización:** muestra el contenido actual del objeto en la salida de la celda.

# %%
nba.info()

# %% [markdown]
# ### Explicación de la línea
# `nba.info()`
# **Inspección:** resume columnas, tipos de datos y valores no nulos.

# %%
nba

# %% [markdown]
# ### Explicación de la línea
# `nba`
# **Visualización:** muestra el contenido actual del objeto en la salida de la celda.

# %%
nba.dropna(how="all")

# %% [markdown]
# ### Explicación de la línea
# `nba.dropna(how="all")`
# **Limpieza:** elimina filas o columnas con valores nulos según `how`, `axis` o `subset`.

# %%
nba.dropna(axis = 0)

# %% [markdown]
# ### Explicación de la línea
# `nba.dropna(axis = 0)`
# **Limpieza:** elimina filas o columnas con valores nulos según `how`, `axis` o `subset`.

# %%
nba.dropna(axis=1)

# %% [markdown]
# ### Explicación de la línea
# `nba.dropna(axis=1)`
# **Limpieza:** elimina filas o columnas con valores nulos según `how`, `axis` o `subset`.

# %%
nba.dropna(subset = ["Name", "Salary", "College"])

# %% [markdown]
# ### Explicación de la línea
# `nba.dropna(subset = ["Name", "Salary", "College"])`
# **Limpieza:** elimina filas o columnas con valores nulos según `how`, `axis` o `subset`.
