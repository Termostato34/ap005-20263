# %%
import pandas as pd

# %% [markdown]
# ### Explicación de la línea
# `import pandas as pd`
# **Importación:** carga **pandas** con el alias `pd` para manipular tablas y series de datos.

# %%
fortune = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/fortune1000.csv")

# %% [markdown]
# ### Explicación de la línea
# `fortune = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/fortune1000.csv")`
# **Lectura:** importa `fortune1000.csv` y almacena las empresas en `fortune`.

# %%
fortune = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/fortune1000.csv", index_col = "Rank")

# %% [markdown]
# ### Explicación de la línea
# `fortune = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/fortune1000.csv", index_col = "Rank")`
# **Lectura:** importa `fortune1000.csv` y almacena las empresas en `fortune`.

# %%
fortune

# %% [markdown]
# ### Explicación de la línea
# `fortune`
# **Visualización:** muestra el contenido actual del objeto en la salida de la celda.

# %%
fortune.info()

# %% [markdown]
# ### Explicación de la línea
# `fortune.info()`
# **Inspección:** resume columnas, tipos de datos y valores no nulos.

# %%
fortune.head(3)

# %% [markdown]
# ### Explicación de la línea
# `fortune.head(3)`
# **Vista previa:** muestra las primeras filas para comprobar la carga y estructura de los datos.

# %%
fortune.groupby('Sector')

# %% [markdown]
# ### Explicación de la línea
# `fortune.groupby('Sector')`
# **Agrupación:** organiza las filas por `Sector` para resumir o consultar cada grupo.

# %%
x = fortune.groupby('Sector')

# %% [markdown]
# ### Explicación de la línea
# `x = fortune.groupby('Sector')`
# **Agrupación:** organiza las filas por `Sector` para resumir o consultar cada grupo.

# %%
type(x)

# %% [markdown]
# ### Explicación de la línea
# `type(x)`
# **Inspección de tipo:** comprueba la clase de objeto que devuelve `groupby`.

# %%
x

# %% [markdown]
# ### Explicación de la línea
# `x`
# **Visualización:** muestra el contenido actual del objeto en la salida de la celda.

# %%
import pandas as pd

# %% [markdown]
# ### Explicación de la línea
# `import pandas as pd`
# **Importación:** carga **pandas** con el alias `pd` para manipular tablas y series de datos.

# %%
df = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/fortune1000.csv")

# %% [markdown]
# ### Explicación de la línea
# `df = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/fortune1000.csv")`
# **Lectura:** importa el archivo Fortune 1000 en `df` sin cambiar su índice.

# %%
sector = df.groupby('Sector')

# %% [markdown]
# ### Explicación de la línea
# `sector = df.groupby('Sector')`
# **Agrupación:** organiza las filas por `Sector` para resumir o consultar cada grupo.

# %%
df.head(5)

# %% [markdown]
# ### Explicación de la línea
# `df.head(5)`
# **Vista previa:** muestra las primeras filas para comprobar la carga y estructura de los datos.

# %%
sector

# %% [markdown]
# ### Explicación de la línea
# `sector`
# **Visualización:** muestra el contenido actual del objeto en la salida de la celda.

# %%
df["Sector"].unique()

# %% [markdown]
# ### Explicación de la línea
# `df["Sector"].unique()`
# **Valores únicos:** lista los sectores distintos de la columna `Sector`.

# %%
sector.size()

# %% [markdown]
# ### Explicación de la línea
# `sector.size()`
# **Tamaño de grupos:** cuenta cuántas filas contiene cada sector.

# %%
df["Sector"].value_counts()

# %% [markdown]
# ### Explicación de la línea
# `df["Sector"].value_counts()`
# **Frecuencias:** cuenta las apariciones de cada valor; `ascending=True` ordena de menor a mayor.

# %%
sector.first()

# %% [markdown]
# ### Explicación de la línea
# `sector.first()`
# **Resumen de grupos:** obtiene la primera fila de cada sector.

# %%
sector.last()

# %% [markdown]
# ### Explicación de la línea
# `sector.last()`
# **Resumen de grupos:** obtiene la última fila de cada sector.

# %%
sector.get_group("Retailing")

# %% [markdown]
# ### Explicación de la línea
# `sector.get_group("Retailing")`
# **Consulta de grupo:** extrae únicamente las empresas del sector solicitado.

# %%
sector.get_group("Health Care")

# %% [markdown]
# ### Explicación de la línea
# `sector.get_group("Health Care")`
# **Consulta de grupo:** extrae únicamente las empresas del sector solicitado.

# %%
#sector.get_group("Energy")

# %% [markdown]
# ### Explicación de la línea
# `#sector.get_group("Energy")`
# **Comentario:** documenta la intención del ejercicio y no se ejecuta porque comienza con `#`.

# %%
df["Sector"] == "Energy"

# %% [markdown]
# ### Explicación de la línea
# `df["Sector"] == "Energy"`
# **Comparación:** crea una condición booleana que identifica las filas del sector `Energy`.

# %%
mask = df["Sector"] == "Energy"

# %% [markdown]
# ### Explicación de la línea
# `mask = df["Sector"] == "Energy"`
# **Comparación:** crea una condición booleana que identifica las filas del sector `Energy`.

# %%
df[mask]

# %% [markdown]
# ### Explicación de la línea
# `df[mask]`
# **Filtrado:** conserva solo las filas cuya máscara vale `True`.

# %%
#df.set_index("Rank", inplace = True)

# %% [markdown]
# ### Explicación de la línea
# `#df.set_index("Rank", inplace = True)`
# **Comentario:** documenta la intención del ejercicio y no se ejecuta porque comienza con `#`.

# %%
df

# %% [markdown]
# ### Explicación de la línea
# `df`
# **Visualización:** muestra el contenido actual del objeto en la salida de la celda.

# %%
sector.sum()

# %% [markdown]
# ### Explicación de la línea
# `sector.sum()`
# **Agregación:** suma los valores numéricos de cada grupo o columna seleccionada.

# %%
sector["Employees"].sum()

# %% [markdown]
# ### Explicación de la línea
# `sector["Employees"].sum()`
# **Agregación:** suma los valores numéricos de cada grupo o columna seleccionada.

# %%
sector["Employees"].mean()

# %% [markdown]
# ### Explicación de la línea
# `sector["Employees"].mean()`
# **Agregación:** calcula el promedio de cada grupo o columna seleccionada.

# %%
sector.agg({"Revenues" : "mean", "Profits" : "mean", "Employees" : "sum"})

# %% [markdown]
# ### Explicación de la línea
# `sector.agg({"Revenues" : "mean", "Profits" : "mean", "Employees" : "sum"})`
# **Agregación múltiple:** aplica las funciones estadísticas indicadas a columnas concretas.

# %%
sector.agg({"Revenues" : ["mean", "max"], "Profits" : "mean", "Employees" : "sum"})

# %% [markdown]
# ### Explicación de la línea
# `sector.agg({"Revenues" : ["mean", "max"], "Profits" : "mean", "Employees" : "sum"})`
# **Agregación múltiple:** aplica las funciones estadísticas indicadas a columnas concretas.

# %%
sector.agg({"Revenues" : ["mean", "max"], "Profits" : ["max", "min"], "Employees" : "sum"})

# %% [markdown]
# ### Explicación de la línea
# `sector.agg({"Revenues" : ["mean", "max"], "Profits" : ["max", "min"], "Employees" : "sum"})`
# **Agregación múltiple:** aplica las funciones estadísticas indicadas a columnas concretas.

# %%
fortune = df

# %% [markdown]
# ### Explicación de la línea
# `fortune = df`
# **Asignación:** hace que `fortune` apunte al DataFrame `df`, reutilizando los datos sin copiar la tabla.

# %%
fortune

# %% [markdown]
# ### Explicación de la línea
# `fortune`
# **Visualización:** muestra el contenido actual del objeto en la salida de la celda.

# %%
sectors = fortune.groupby('Sector')

# %% [markdown]
# ### Explicación de la línea
# `sectors = fortune.groupby('Sector')`
# **Agrupación:** organiza las filas por `Sector` para resumir o consultar cada grupo.

# %%
fortune

# %% [markdown]
# ### Explicación de la línea
# `fortune`
# **Visualización:** muestra el contenido actual del objeto en la salida de la celda.

# %%
sector.size()

# %% [markdown]
# ### Explicación de la línea
# `sector.size()`
# **Tamaño de grupos:** cuenta cuántas filas contiene cada sector.

# %%
df = pd.DataFrame(columns = fortune.columns)

# %% [markdown]
# ### Explicación de la línea
# `df = pd.DataFrame(columns = fortune.columns)`
# **Inicialización:** crea un DataFrame vacío llamado `df` usando las mismas columnas que `fortune`, preparado para acumular resultados.

# %%
df

# %% [markdown]
# ### Explicación de la línea
# `df`
# **Visualización:** muestra el contenido actual del objeto en la salida de la celda.

# %%
for sector, values in sectors:

# %% [markdown]
# ### Explicación de la línea
# `for sector, values in sectors:`
# **Bucle:** recorre cada sector y su DataFrame asociado para repetir el análisis.

# %%
  company_with_highest_profit = values.nlargest(1, "Profits")

# %% [markdown]
# ### Explicación de la línea
# `  company_with_highest_profit = values.nlargest(1, "Profits")`
# **Selección de máximos:** obtiene la empresa con mayor beneficio del grupo actual.

# %%
  df = df.append(company_with_highest_profit)

# %% [markdown]
# ### Explicación de la línea
# `  df = df.append(company_with_highest_profit)`
# **Acumulación:** añade a `df` la empresa con mayor beneficio del grupo actual.
