# %%
import pandas as pd

# %% [markdown]
# ### Explicación de la línea
# `import pandas as pd`
# **Importación:** carga **pandas** con el alias `pd` para manipular tablas y series de datos.

# %%
emp = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Employee.csv")

# %% [markdown]
# ### Explicación de la línea
# `emp = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Employee.csv")`
# **Lectura:** carga `Employee.csv` en `emp` para analizar empleados y categorías.

# %%
emp.head()

# %% [markdown]
# ### Explicación de la línea
# `emp.head()`
# **Vista previa:** muestra las primeras filas para comprobar la carga y estructura de los datos.

# %%
emp.info()

# %% [markdown]
# ### Explicación de la línea
# `emp.info()`
# **Inspección:** resume columnas, tipos de datos y valores no nulos.

# %%
emp.nunique()

# %% [markdown]
# ### Explicación de la línea
# `emp.nunique()`
# **Conteo:** calcula cuántos valores diferentes hay en cada columna de `emp`.

# %%
emp[["department", "position"]] = emp[["department", "position"]].astype("category")

# %% [markdown]
# ### Explicación de la línea
# `emp[["department", "position"]] = emp[["department", "position"]].astype("category")`
# **Conversión de tipo:** transforma la columna en una categoría para representar valores repetidos eficientemente.

# %%
emp.info()

# %% [markdown]
# ### Explicación de la línea
# `emp.info()`
# **Inspección:** resume columnas, tipos de datos y valores no nulos.

# %%
"happy".upper()

# %% [markdown]
# ### Explicación de la línea
# `"happy".upper()`
# **Texto:** `upper()` convierte `happy` a mayúsculas.

# %%
"PYTHON".lower()

# %% [markdown]
# ### Explicación de la línea
# `"PYTHON".lower()`
# **Texto:** `lower()` convierte `PYTHON` a minúsculas.

# %%
emp["name"]

# %% [markdown]
# ### Explicación de la línea
# `emp["name"]`
# **Selección:** extrae la Serie `name` del DataFrame `emp` para consultar los nombres de empleados.

# %%
emp["name"].str.lower().str.title()

# %% [markdown]
# ### Explicación de la línea
# `emp["name"].str.lower().str.title()`
# **Normalización de texto:** pasa los nombres a minúsculas y luego aplica formato de título.
