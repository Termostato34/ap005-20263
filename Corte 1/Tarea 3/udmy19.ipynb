# %%
#Refine Dataframe using Multiple Conditions AND

# %% [markdown]
# ### Explicación de la línea
# `#Refine Dataframe using Multiple Conditions AND`
# **Comentario:** documenta la intención del ejercicio y no se ejecuta porque comienza con `#`.

# %%
import pandas as pd

# %% [markdown]
# ### Explicación de la línea
# `import pandas as pd`
# **Importación:** carga **pandas** con el alias `pd` para manipular tablas y series de datos.

# %%
#insta = pd.read_csv('/content/drive/MyDrive/udmy/dataAnalisys/Instagram.csv')

# %% [markdown]
# ### Explicación de la línea
# `#insta = pd.read_csv('/content/drive/MyDrive/udmy/dataAnalisys/Instagram.csv')`
# **Comentario:** documenta la intención del ejercicio y no se ejecuta porque comienza con `#`.

# %%
insta = pd.read_csv('/content/drive/MyDrive/udmy/dataAnalisys/Instagram.csv', parse_dates = ["reg date", "last login"])

# %% [markdown]
# ### Explicación de la línea
# `insta = pd.read_csv('/content/drive/MyDrive/udmy/dataAnalisys/Instagram.csv', parse_dates = ["reg date", "last login"])`
# **Lectura:** importa el archivo de Instagram en `insta`; `parse_dates` convierte las fechas.

# %%
insta["gender"] = insta["gender"].astype("category")

# %% [markdown]
# ### Explicación de la línea
# `insta["gender"] = insta["gender"].astype("category")`
# **Conversión de tipo:** transforma la columna en una categoría para representar valores repetidos eficientemente.

# %%
insta["Country"] = insta["Country"].astype("category")

# %% [markdown]
# ### Explicación de la línea
# `insta["Country"] = insta["Country"].astype("category")`
# **Conversión de tipo:** transforma la columna en una categoría para representar valores repetidos eficientemente.

# %%
insta["Influencer"] = insta["Influencer"].astype("bool")

# %% [markdown]
# ### Explicación de la línea
# `insta["Influencer"] = insta["Influencer"].astype("bool")`
# **Conversión de tipo:** transforma `Influencer` en valores booleanos `True` o `False`.

# %%
insta.head()

# %% [markdown]
# ### Explicación de la línea
# `insta.head()`
# **Vista previa:** muestra las primeras filas para comprobar la carga y estructura de los datos.

# %%
from google.colab import drive

# %% [markdown]
# ### Explicación de la línea
# `from google.colab import drive`
# **Importación:** obtiene `drive` de Google Colab para conectar el cuaderno con Google Drive.

# %%
drive.mount('/content/drive')

# %% [markdown]
# ### Explicación de la línea
# `drive.mount('/content/drive')`
# **Montaje:** conecta Google Drive en `/content/drive` para leer archivos almacenados allí.

# %%
#Print our Male instagram users that joined since 2016 and they are from USA

# %% [markdown]
# ### Explicación de la línea
# `#Print our Male instagram users that joined since 2016 and they are from USA`
# **Comentario:** documenta la intención del ejercicio y no se ejecuta porque comienza con `#`.

# %%
mask = (insta["gender"] == "Male") & (insta["reg date"] > "2015-12-31") & (insta["Country"] == "United States")

# %% [markdown]
# ### Explicación de la línea
# `mask = (insta["gender"] == "Male") & (insta["reg date"] > "2015-12-31") & (insta["Country"] == "United States")`
# **Máscara:** guarda una condición booleana reutilizable para filtrar el DataFrame.

# %%
insta[mask]

# %% [markdown]
# ### Explicación de la línea
# `insta[mask]`
# **Filtrado:** conserva solo las filas cuya máscara vale `True`.

# %%
mask1 = insta["gender"] == "Male"

# %% [markdown]
# ### Explicación de la línea
# `mask1 = insta["gender"] == "Male"`
# **Asignación de columnas:** guarda el resultado transformado en las columnas seleccionadas.

# %%
mask2 = insta["reg date"] > "2015-12-31"

# %% [markdown]
# ### Explicación de la línea
# `mask2 = insta["reg date"] > "2015-12-31"`
# **Máscara temporal:** identifica los usuarios cuya fecha de registro es posterior al 31 de diciembre de 2015.

# %%
mask3 = insta["Country"] == "United States"

# %% [markdown]
# ### Explicación de la línea
# `mask3 = insta["Country"] == "United States"`
# **Asignación de columnas:** guarda el resultado transformado en las columnas seleccionadas.

# %%
insta[mask1 & mask2 & mask3]

# %% [markdown]
# ### Explicación de la línea
# `insta[mask1 & mask2 & mask3]`
# **Filtrado:** conserva solo las filas cuya máscara vale `True`.

# %%
mask = (insta["gender"] == "male") & (insta["reg date"] > "2015-12-31")

# %% [markdown]
# ### Explicación de la línea
# `mask = (insta["gender"] == "male") & (insta["reg date"] > "2015-12-31")`
# **Máscara:** guarda una condición booleana reutilizable para filtrar el DataFrame.

# %%
insta[mask]

# %% [markdown]
# ### Explicación de la línea
# `insta[mask]`
# **Filtrado:** conserva solo las filas cuya máscara vale `True`.
