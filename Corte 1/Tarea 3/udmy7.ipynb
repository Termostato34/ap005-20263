# %%
import pandas as pd

# %% [markdown]
# ### Explicación de la línea
# `import pandas as pd`
# **Importación:** carga **pandas** con el alias `pd` para manipular tablas y series de datos.

# %%
nba = pd.read_excel("Nba Teams.xlsx")

# %% [markdown]
# ### Explicación de la línea
# `nba = pd.read_excel("Nba Teams.xlsx")`
# **Lectura:** `pd.read_excel` carga el archivo de Excel en el DataFrame `nba`.

# %%
nba.head()

# %% [markdown]
# ### Explicación de la línea
# `nba.head()`
# **Vista previa:** muestra las primeras filas para comprobar la carga y estructura de los datos.

# %%
nba["Teams"] = " "

# %% [markdown]
# ### Explicación de la línea
# `nba["Teams"] = " "`
# **Selección:** accede a la columna indicada de `nba` como una Serie.

# %%
nba["nba Teams"] = " "

# %% [markdown]
# ### Explicación de la línea
# `nba["nba Teams"] = " "`
# **Selección:** accede a la columna indicada de `nba` como una Serie.

# %%
nba.head()

# %% [markdown]
# ### Explicación de la línea
# `nba.head()`
# **Vista previa:** muestra las primeras filas para comprobar la carga y estructura de los datos.

# %%
#nba.Name

# %% [markdown]
# ### Explicación de la línea
# `#nba.Name`
# **Comentario:** documenta la intención del ejercicio y no se ejecuta porque comienza con `#`.

# %%
#nba.nba Teams

# %% [markdown]
# ### Explicación de la línea
# `#nba.nba Teams`
# **Comentario:** documenta la intención del ejercicio y no se ejecuta porque comienza con `#`.

# %%
nba.Teams

# %% [markdown]
# ### Explicación de la línea
# `nba.Teams`
# **Selección por atributo:** muestra la columna `Teams`, creada anteriormente en `nba`.

# %%
#nba.Sports

# %% [markdown]
# ### Explicación de la línea
# `#nba.Sports`
# **Comentario:** documenta la intención del ejercicio y no se ejecuta porque comienza con `#`.

# %%
nba["Sports"] = "basket"

# %% [markdown]
# ### Explicación de la línea
# `nba["Sports"] = "basket"`
# **Selección:** accede a la columna indicada de `nba` como una Serie.

# %%
nba.head()

# %% [markdown]
# ### Explicación de la línea
# `nba.head()`
# **Vista previa:** muestra las primeras filas para comprobar la carga y estructura de los datos.

# %%
nba.drop("Teams", axis = 1, inplace = True)

# %% [markdown]
# ### Explicación de la línea
# `nba.drop("Teams", axis = 1, inplace = True)`
# **Eliminación:** quita la columna indicada; `axis=1` señala que se trata de una columna.

# %%
#nba.insert(2, column = "Teams", value = "Colombians")

# %% [markdown]
# ### Explicación de la línea
# `#nba.insert(2, column = "Teams", value = "Colombians")`
# **Comentario:** documenta la intención del ejercicio y no se ejecuta porque comienza con `#`.

# %%
#nba.insert(2, column = "Sportss", value = "TurmequÃ©")

# %% [markdown]
# ### Explicación de la línea
# `#nba.insert(2, column = "Sportss", value = "TurmequÃ©")`
# **Comentario:** documenta la intención del ejercicio y no se ejecuta porque comienza con `#`.

# %%
nba

# %% [markdown]
# ### Explicación de la línea
# `nba`
# **Visualización:** muestra el contenido actual del objeto en la salida de la celda.

# %%
nba

# %% [markdown]
# ### Explicación de la línea
# `nba`
# **Visualización:** muestra el contenido actual del objeto en la salida de la celda.

# %%
nba.insert(2, column = "Teams", value = "Colombians")

# %% [markdown]
# ### Explicación de la línea
# `nba.insert(2, column = "Teams", value = "Colombians")`
# **Inserción:** añade una columna en la posición indicada con el nombre y valor especificados.

# %%
nba

# %% [markdown]
# ### Explicación de la línea
# `nba`
# **Visualización:** muestra el contenido actual del objeto en la salida de la celda.
